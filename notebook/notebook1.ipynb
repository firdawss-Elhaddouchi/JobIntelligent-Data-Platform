# %%
import requests

# %%
api_keys = '5f08f697-2811-4c29-b1dd-77db0440416b'
base_url = 'https://www.reed.co.uk/api/1.0/search'# ?keywords=accountant&location=london&employerid=123&distancefromlocation=15'
prm = {'keywords':'data','location':'london'}
response = requests.get(base_url,auth=(api_keys,''))
if response.status_code == 200:
    rep = response.json()['results']

# %%
rep
# Out:
# [{'jobId': 56743369,
#   'employerId': 696975,
#   'employerName': 'Costa Coffee',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Team Leader',
#   'locationName': 'CB62FR',
#   'minimumSalary': 11.1,
#   'maximumSalary': 12.9,
#   'currency': 'GBP',
#   'expirationDate': '16/05/2026',
#   'date': '04/04/2026',
#   'jobDescription': 'Overview Team Leader Here at Costa Coffee, we want to inspire the world to love great coffee. Were all about embracing passion, energy and teamwork to serve memorable moments for every one of our customers. If youre an aspiring Store Manager ready to head up a team, this could be the perfect role for you. A bit about the role As a Barista Maestro (Team Leader), youll have your first taste of leadership responsibility, accountability and autonomy... ',
#   'applications': 0,
#   'jobUrl': 'https://www.reed.co.uk/jobs/team-leader/56743369'},
#  {'jobId': 56688699,
#   'employerId': 696975,
#   'employerName': 'Costa Coffee',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Team Leader',
#   'locationName': 'SR77DR',
#   'minimumSalary': 12.5,
#   'maximumSalary': 12.5,
#   'currency': 'GBP',
#   'expirationDate': '04/05/2026',
#   'date': '23/03/2026',
#   'jobDescription': 'Overview Team Leader Here at Cuppacoff we are a large diverse organisation that operates a broad range of hospitality franchises across the UK. We aspire to be the best of the best and reflect this in our teams across the country.One of our franchises is Costa Coffee, we want to join them in their mission to inspire the world to love great coffee. Were all about embracing passion, energy and teamwork to serve memorable moments for every one of o... ',
#   'applications': 0,
#   'jobUrl': 'https://www.reed.co.uk/jobs/team-leader/56688699'},
#  {'jobId': 56707989,
#   'employerId': 596445,
#   'employerName': 'CV TECHNICAL LTD',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Maintenance Engineer',
#   'locationName': 'Winsford',
#   'minimumSalary': 37000.0,
#   'maximumSalary': 45000.0,
#   'currency': 'GBP',
#   'expirationDate': '08/05/2026',
#   'date': '27/03/2026',
#   'jobDescription': 'Maintenance Engineer (Mecahnical or Electrical) Winsford, Cheshire Days, Mon-Fri (07:30-15:30) 37-43,000 We are looking for a motivated Maintenance Engineer to join a market leading company in their respective field. Reporting directly to the maintenance manager you will be a key member in ensuring the production facility is kept running. You will be involved in all aspects of planned and reactive maintenance within their operation. With progres... ',
#   'applications': 5,
#   'jobUrl': 'https://www.reed.co.uk/jobs/maintenance-engineer/56707989'},
#  {'jobId': 56719025,
#   'employerId': 524744,
#   'employerName': 'Hays Specialist Recruitment Limited',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Independent Domestic Violence Advisor',
#   'locationName': 'West Midlands (Region)',
#   'minimumSalary': 25282.0,
#   'maximumSalary': 28861.0,
#   'currency': 'GBP',
#   'expirationDate': '12/05/2026',
#   'date': '31/03/2026',
#   'jobDescription': 'Your new company You will be joining a respected specialist domestic abuse support provider operating across the Black Country. The service delivers trauma-informed, holistic support to individuals and families experiencing domestic abuse, with a strong emphasis on empowerment, safety and recovery. This particular role sits within the Family Court Pathfinder Programme, a national initiative designed to improve how Family Courts respond to cases ... ',
#   'applications': 2,
#   'jobUrl': 'https://www.reed.co.uk/jobs/independent-domestic-violence-advisor/56719025'},
#  {'jobId': 56719024,
#   'employerId': 575264,
#   'employerName': 'Reed',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Accounts Assistant',
#   'locationName': 'ME103EU',
#   'minimumSalary': 25000.0,
#   'maximumSalary': 30000.0,
#   'currency': 'GBP',
#   'expirationDate': '30/04/2026',
#   'date': '31/03/2026',
#   'jobDescription': 'Reed are supporting our Sittingbourne client, who are seeking an Accounts Assistant to join our team. The ideal candidate will support our financial department by performing a range of accounting tasks. Responsibilities You must have excellent Data Entry skills and strong attention to detail along with good numeracy skills. Previous Sales &amp; Purchase invoicing, accounts or Data Entry experience would be required. Entering Purchasing Invoice’s... ',
#   'applications': 13,
#   'jobUrl': 'https://www.reed.co.uk/jobs/accounts-assistant/56719024'},
#  {'jobId': 56687098,
#   'employerId': 619009,
#   'employerName': 'TC Group',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Accounts Apprentice',
#   'locationName': 'Borehamwood',
#   'minimumSalary': None,
#   'maximumSalary': None,
#   'currency': None,
#   'expirationDate': '20/04/2026',
#   'date': '23/03/2026',
#   'jobDescription': 'Salary&nbsp; – competitive depending on experience Hours - Monday to Friday, 35 hours per week Holiday&nbsp; – 20 days annual leave (excluding bank holidays) About the Apprentice role We are TC Group, the fastest-growing top 20 accountancy firm in the UK. We’re business advisors and accountants, with over 30 years of experience we’ve honed our skills and developed our service offering to deliver a much wider range of bespoke support and advice t... ',
#   'applications': 30,
#   'jobUrl': 'https://www.reed.co.uk/jobs/accounts-apprentice/56687098'},
#  {'jobId': 56707988,
#   'employerId': 601332,
#   'employerName': 'Pertemps Leicester',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Vehicle Technician',
#   'locationName': 'Arnold',
#   'minimumSalary': 19.25,
#   'maximumSalary': 19.25,
#   'currency': 'GBP',
#   'expirationDate': '08/05/2026',
#   'date': '27/03/2026',
#   'jobDescription': 'Job Title: Vehicle Technician (Temporary – Potential for Permanent Role) Location: Arnold, Nottingham Start Date: Ideally by 6th April 2026 Job Overview: We are seeking a reliable and skilled Vehicle Technician to join our small team on a temporary basis, with the potential for a permanent position due to upcoming staff changes. This is an excellent opportunity for a motivated individual who can work independently while maintaining high standard... ',
#   'applications': 3,
#   'jobUrl': 'https://www.reed.co.uk/jobs/vehicle-technician/56707988'},
#  {'jobId': 56687097,
#   'employerId': 519141,
#   'employerName': 'TEMPLEGATE RECRUITMENT',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Wealth Managment Administrator',
#   'locationName': 'ST158QW',
#   'minimumSalary': 26000.0,
#   'maximumSalary': 30000.0,
#   'currency': 'GBP',
#   'expirationDate': '04/05/2026',
#   'date': '23/03/2026',
#   'jobDescription': 'Templegate Recruitment Specialist Recruiters in Financial Services Job Title: Client Services Administrator Location: Stone, Staffordshire (In-person) Salary: 26,000 - 30,000 per year Benefits: 25 days’ holiday plus bank holidays, two extra days after Christmas Additional holiday entitlement after 5 years’ service Option to purchase extra holiday days after 1 year Birthday day off after 1 year Employer pension contributions (e.g., 5% employer / ... ',
#   'applications': 2,
#   'jobUrl': 'https://www.reed.co.uk/jobs/wealth-managment-administrator/56687097'},
#  {'jobId': 56707987,
#   'employerId': 687139,
#   'employerName': 'Pertemps Scotland Temps',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Executive Administrator',
#   'locationName': 'Clydebank',
#   'minimumSalary': 30000.0,
#   'maximumSalary': 35000.0,
#   'currency': 'GBP',
#   'expirationDate': '08/05/2026',
#   'date': '27/03/2026',
#   'jobDescription': 'Executive Administrator Location: Glasgow (Head Office) Salary: Up to 30,000 (with flexibility for the right candidate) Hours: Full-time, 35 hours per week We are delighted to be partnering with a well-established and growing organisation to recruit an Executive Administrator to support at senior leadership level. This is a pivotal, fast-paced position offering the opportunity to work closely with a key member of the executive team, providing hi... ',
#   'applications': 17,
#   'jobUrl': 'https://www.reed.co.uk/jobs/executive-administrator/56707987'},
#  {'jobId': 56687096,
#   'employerId': 325295,
#   'employerName': 'Perfect Placement Uk Ltd',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Service Controller',
#   'locationName': 'SL62PZ',
#   'minimumSalary': 30000.0,
#   'maximumSalary': 30000.0,
#   'currency': 'GBP',
#   'expirationDate': '04/05/2026',
#   'date': '23/03/2026',
#   'jobDescription': 'Are you an experienced Service Controller seeking a rewarding opportunity within a reputable fleet business in Maidenhead? Our client, a well-established company specialising in forklift and material handling fleet management, is looking to recruit a dedicated Service Controller to join their dynamic team. This position offers a competitive salary up to 30,000, negotiable based on your experience, alongside excellent benefits and clear career pr... ',
#   'applications': 6,
#   'jobUrl': 'https://www.reed.co.uk/jobs/service-controller/56687096'},
#  {'jobId': 56719022,
#   'employerId': 418809,
#   'employerName': 'Gleeson Recruitment Group',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Financial Accountant',
#   'locationName': 'Warwickshire',
#   'minimumSalary': 50000.0,
#   'maximumSalary': 55000.0,
#   'currency': 'GBP',
#   'expirationDate': '12/05/2026',
#   'date': '31/03/2026',
#   'jobDescription': 'This role delivers statutory reporting, manages external audits, maintains financial controls, and ensures compliance with accounting standards. It supports budgeting, financial analysis, and decision-making while improving finance systems and processes. The organisation is a values-driven not-for-profit that promotes innovation, self-directed learning, and global collaboration. The role suits someone who works independently, communicates clearl... ',
#   'applications': 4,
#   'jobUrl': 'https://www.reed.co.uk/jobs/financial-accountant/56719022'},
#  {'jobId': 56719023,
#   'employerId': 142490,
#   'employerName': 'Law Support',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Billing Clerk',
#   'locationName': 'EC2V5BR',
#   'minimumSalary': 40000.0,
#   'maximumSalary': 46000.0,
#   'currency': 'GBP',
#   'expirationDate': '12/05/2026',
#   'date': '31/03/2026',
#   'jobDescription': 'Our client, a highly regarded law firm based in central London are looking to recruit an experienced Legal Billing Assistant. This is an excellent opportunity for someone looking to build a long-term career within a supportive, fast-paced environment. For this position you must have a minimum of two years previous billing assistant experience within a law firm. About the Role The Finance team plays a vital role in delivering a first-class servic... ',
#   'applications': 22,
#   'jobUrl': 'https://www.reed.co.uk/jobs/billing-clerk/56719023'},
#  {'jobId': 56719021,
#   'employerId': 147937,
#   'employerName': 'Recruitment Solutions (North West) Ltd',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Industrial Electrician',
#   'locationName': 'BL96GG',
#   'minimumSalary': 40000.0,
#   'maximumSalary': 40000.0,
#   'currency': 'GBP',
#   'expirationDate': '12/05/2026',
#   'date': '31/03/2026',
#   'jobDescription': 'We are seeking an experienced Industrial Electrician to join the UK’s leading manufacturer of machinery safety systems and paint spray booths. You will be responsible for installing, wiring, repairing, and maintaining electrical systems on advanced machinery at client sites across the UK and occasionally overseas. Industrial Electrician - Responsibilities: Travel to client sites to perform full electrical installations on new machinery. Interpre... ',
#   'applications': 2,
#   'jobUrl': 'https://www.reed.co.uk/jobs/industrial-electrician/56719021'},
#  {'jobId': 56719020,
#   'employerId': 692377,
#   'employerName': 'Bespoke Career Solutions Ltd',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Manual Machinist / Conventional Lathe Operator',
#   'locationName': 'WS87DG',
#   'minimumSalary': 13.0,
#   'maximumSalary': 15.0,
#   'currency': 'GBP',
#   'expirationDate': '12/05/2026',
#   'date': '31/03/2026',
#   'jobDescription': 'Manual Turner Location: Brownhills Job Type: Temporary to Permanent Pay Rate: (negotiable depending on experience) Hours: Day shifts with regular overtime available Why join this opportunity? Competitive hourly rate with room to increase based on your experience Overtime paid at enhanced rates Stable, long-term opportunity with permanent prospects Friendly, well-established engineering environment Immediate start available About the role Are you... ',
#   'applications': 0,
#   'jobUrl': 'https://www.reed.co.uk/jobs/manual-machinist-conventional-lathe-operator/56719020'},
#  {'jobId': 56707986,
#   'employerId': 254966,
#   'employerName': 'VPss',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'HGV Mechanical Engineer',
#   'locationName': 'Gatwick',
#   'minimumSalary': 46000.0,
#   'maximumSalary': 47000.0,
#   'currency': 'GBP',
#   'expirationDate': '08/05/2026',
#   'date': '27/03/2026',
#   'jobDescription': 'A Ground Support Equipment (GSE) Mechanical Engineers main responsibilities will be to help maintain, repair, and operate my clients specialised vehicles and equipment located at Gatwick Airport. Mechanical Engineer benefits 46,000 - 47,000 base salary 6% employer pension contribution 3x salary Life Assurance Private Medical coverage Employee Assistance Programme (EAP) Working hours: choose which option fits you best: 4 day on 4 days off (6am – ... ',
#   'applications': 1,
#   'jobUrl': 'https://www.reed.co.uk/jobs/hgv-mechanical-engineer/56707986'},
#  {'jobId': 56719019,
#   'employerId': 418633,
#   'employerName': 'Shorterm Group',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Maintenance Engineer',
#   'locationName': 'Wolverhampton',
#   'minimumSalary': 41.0,
#   'maximumSalary': 44.0,
#   'currency': 'GBP',
#   'expirationDate': '12/05/2026',
#   'date': '31/03/2026',
#   'jobDescription': "Location: Wolverhampton Rate: 41-44 per hour (Umbrella PAYE) Salary Equivalent: 62-65k Shift Pattern: Double Days (This will possibly change at the end of 2026) Contract: Temp-to-perm Overview A great opportunity to join a modern manufacturing environment supporting advanced automated production technologies. You'll be part of a skilled maintenance team responsible for ensuring high-volume machinery and systems operate reliably and safely. Ongoi... ",
#   'applications': 1,
#   'jobUrl': 'https://www.reed.co.uk/jobs/maintenance-engineer/56719019'},
#  {'jobId': 56687094,
#   'employerId': 477350,
#   'employerName': 'Michael Page Finance',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Semi-Senior Auditor',
#   'locationName': 'Sittingbourne',
#   'minimumSalary': 28000.0,
#   'maximumSalary': 35000.0,
#   'currency': 'GBP',
#   'expirationDate': '20/04/2026',
#   'date': '23/03/2026',
#   'jobDescription': "We're seeking a diligent Semi-Senior Auditor to join our Accounting &amp; Finance department. The ideal candidate will be responsible for conducting thorough financial statement audits and ensuring compliance with regulations in our professional services setting. Client Details Our client is a medium-sized organisation in the professional services industry. With a strong reputation in Sittingbourne, they pride themselves on delivering exceptiona... ",
#   'applications': 1,
#   'jobUrl': 'https://www.reed.co.uk/jobs/semi-senior-auditor/56687094'},
#  {'jobId': 56687093,
#   'employerId': 379777,
#   'employerName': 'Yolk Recruitment Ltd',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Private Client Lawyer',
#   'locationName': 'BS84EJ',
#   'minimumSalary': 65000.0,
#   'maximumSalary': 65000.0,
#   'currency': 'GBP',
#   'expirationDate': '04/05/2026',
#   'date': '23/03/2026',
#   'jobDescription': 'Private Client Lawyer Bristol Salary up to 65k DOE Yolk Recruitment is proud to be supporting an established and well-regarded law firm with the recruitment of a Private Client Lawyer for its growing department. This is an excellent opportunity for an experienced Private Client Lawyer to join a busy and supportive Wills, Trusts and Estate Administration team, working alongside experienced Partners and a friendly wider team. This Private Client L... ',
#   'applications': 1,
#   'jobUrl': 'https://www.reed.co.uk/jobs/private-client-lawyer/56687093'},
#  {'jobId': 56719018,
#   'employerId': 694785,
#   'employerName': 'The Hyde Group',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Property Clearance Assistant - Removals',
#   'locationName': 'ME11FF',
#   'minimumSalary': 27000.0,
#   'maximumSalary': 27000.0,
#   'currency': 'GBP',
#   'expirationDate': '12/05/2026',
#   'date': '31/03/2026',
#   'jobDescription': 'Property Clearance Assistant (Removals) Rochester – covering postcode area across Dartford,&nbsp;Bromley, Croydon and Medway 27,000 plus company van (caged) and fuel card Hyde is looking to recruit a&nbsp; Property Clearance Assistant to join our Property Services team. Hyde is one of the UK’s leading and award-winning providers of affordable homes across London, the South-East, and surrounding areas. We manage 50,000 homes and provide services ... ',
#   'applications': 1,
#   'jobUrl': 'https://www.reed.co.uk/jobs/property-clearance-assistant-removals/56719018'},
#  {'jobId': 56707985,
#   'employerId': 504568,
#   'employerName': 'Aspire People Limited',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Psychology Graduate SEN TA - Manchester',
#   'locationName': 'Manchester',
#   'minimumSalary': 100.0,
#   'maximumSalary': 110.0,
#   'currency': 'GBP',
#   'expirationDate': '24/04/2026',
#   'date': '27/03/2026',
#   'jobDescription': 'Psychology Graduate SEN Teaching Assistants - Manchester Long-term and Short-term Roles Available Aspire People are working closely with a number of secondary schools across Manchester who are seeking passionate and dedicated Psychology Graduates to join their teams as SEN Teaching Assistants. This is a fantastic opportunity for graduates who are keen to make a real difference to the lives of young people with Special Educational Needs and Disab... ',
#   'applications': 2,
#   'jobUrl': 'https://www.reed.co.uk/jobs/psychology-graduate-sen-ta-manchester/56707985'},
#  {'jobId': 56687091,
#   'employerId': 576919,
#   'employerName': 'Merrifield Consultants',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Learning and Development Lead',
#   'locationName': 'London',
#   'minimumSalary': 35000.0,
#   'maximumSalary': 40000.0,
#   'currency': 'GBP',
#   'expirationDate': '04/05/2026',
#   'date': '23/03/2026',
#   'jobDescription': 'Merrifield Consultants are delighted to be partnering with a membership body for maritime professionals to recruit a proactive and highly organised Learning and Development Lead to oversee the end-to-end delivery of their Academy learning programmes. About the Role As Learning and Development Lead, you will take ownership of the planning, scheduling and delivery of a wide range of learning products, including online courses, workshops, schemes, ... ',
#   'applications': 62,
#   'jobUrl': 'https://www.reed.co.uk/jobs/learning-and-development-lead/56687091'},
#  {'jobId': 56707984,
#   'employerId': 623914,
#   'employerName': 'Richmond Square Consulting Ltd',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Android Software Engineer',
#   'locationName': 'GL501TA',
#   'minimumSalary': 70000.0,
#   'maximumSalary': 85000.0,
#   'currency': 'GBP',
#   'expirationDate': '08/05/2026',
#   'date': '27/03/2026',
#   'jobDescription': 'Android Software Engineer (Kotlin) Cheltenham / Hybrid / Remote My client is looking for an experienced Android Software Engineer with strong Kotlin expertise to join a growing UK technology business delivering secure mobile solutions into the national defence sector. This is an opportunity to work across live programmes, next-generation product development, and cutting-edge proof-of-concept work, using modern Android engineering to solve comple... ',
#   'applications': 7,
#   'jobUrl': 'https://www.reed.co.uk/jobs/android-software-engineer/56707984'},
#  {'jobId': 56719017,
#   'employerId': 300493,
#   'employerName': 'Uxbridge Employment Agency',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Warehouse Operative',
#   'locationName': 'Hayes',
#   'minimumSalary': 30784.0,
#   'maximumSalary': 30784.0,
#   'currency': 'GBP',
#   'expirationDate': '12/05/2026',
#   'date': '31/03/2026',
#   'jobDescription': "Warehouse Operative - Counterbalance &amp; Reach Location:Hayes, Middlesex Salary: 30'784 + performance-related bonuses Contract Type:Permanent Hours:Monday to Friday, alternating shifts (6am-2pm one week / 12pm-8pm the next) A brilliant opportunity has come up with one of our most successful long-term clients - a growing local business in Hayes that offers a friendly, team-focused working culture and genuine long-term stability. They're now loo... ",
#   'applications': 81,
#   'jobUrl': 'https://www.reed.co.uk/jobs/warehouse-operative/56719017'},
#  {'jobId': 56687090,
#   'employerId': 616771,
#   'employerName': 'Keeler Recruitment',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'FP&A Analyst',
#   'locationName': 'NR321XQ',
#   'minimumSalary': 45000.0,
#   'maximumSalary': 50000.0,
#   'currency': 'GBP',
#   'expirationDate': '04/05/2026',
#   'date': '23/03/2026',
#   'jobDescription': 'Job Title: Finance Analyst Location: Lowestoft (fully site based) Salary: 40,000 - 50,000 (DOE) Our client, Birds Eye are looking for a detail-oriented Finance Analyst to join their dynamic finance team. This role involves preparing financial reports, analysing key metrics, and supporting forecasting and budgeting processes. The successful candidate will play a crucial role in providing insights to drive business performance and improve decision... ',
#   'applications': 16,
#   'jobUrl': 'https://www.reed.co.uk/jobs/fp-a-analyst/56687090'},
#  {'jobId': 56687089,
#   'employerId': 626279,
#   'employerName': 'Connect2Luton',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Business Support Officer - Highways Procurement',
#   'locationName': 'Luton',
#   'minimumSalary': 250.0,
#   'maximumSalary': 280.0,
#   'currency': 'GBP',
#   'expirationDate': '04/05/2026',
#   'date': '23/03/2026',
#   'jobDescription': 'Connect2Luton are excited to recruit a Business Support Officer - Highways Procurement on behalf of Luton Borough Council. Job Purpose: To provide high-quality business, administrative, and procurement support to the Highways Service, ensuring efficient delivery of procurement processes, contract administration, supplier management, compliance monitoring Key Responsibilities: Support by Monitoring project milestones and key timelines Support pre... ',
#   'applications': 33,
#   'jobUrl': 'https://www.reed.co.uk/jobs/business-support-officer-highways-procurement/56687089'},
#  {'jobId': 56719016,
#   'employerId': 687776,
#   'employerName': 'JMG Group',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Group Integration Administration Assistant',
#   'locationName': 'Leeds',
#   'minimumSalary': None,
#   'maximumSalary': None,
#   'currency': None,
#   'expirationDate': '12/05/2026',
#   'date': '31/03/2026',
#   'jobDescription': 'JMG Group is a private equity-backed insurance business headquartered in Leeds, with a strong UK-wide presence. As a top 30 broker, we’re rapidly growing through acquisitions, placing 350m+ Gross Written Premium annually. Our market reputation is built on customer excellence, driven by our people, systems, and processes. The opportunity Reporting to the Group Integration Business Manager, you will provide comprehensive administrative support acr... ',
#   'applications': 11,
#   'jobUrl': 'https://www.reed.co.uk/jobs/group-integration-administration-assistant/56719016'},
#  {'jobId': 56687087,
#   'employerId': 325295,
#   'employerName': 'Perfect Placement Uk Ltd',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Bodyshop Manager',
#   'locationName': 'AL95EU',
#   'minimumSalary': 50000.0,
#   'maximumSalary': 50000.0,
#   'currency': 'GBP',
#   'expirationDate': '04/05/2026',
#   'date': '23/03/2026',
#   'jobDescription': 'Are you an experienced Bodyshop Manager seeking a new challenge within a reputable accident repair centre? We are working on behalf of our client to appoint a dedicated Bodyshop Manager who can lead operations with professionalism and efficiency. This is an excellent opportunity for a skilled manager looking to make a significant impact in a well-managed workshop environment. Benefits: Salary up to 50,000, depending on experience Monday to Frida... ',
#   'applications': 4,
#   'jobUrl': 'https://www.reed.co.uk/jobs/bodyshop-manager/56687087'},
#  {'jobId': 56687088,
#   'employerId': 432060,
#   'employerName': 'Academics ',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Learning Support Assistant',
#   'locationName': 'SS131HT',
#   'minimumSalary': 88.0,
#   'maximumSalary': 100.0,
#   'currency': 'GBP',
#   'expirationDate': '04/05/2026',
#   'date': '23/03/2026',
#   'jobDescription': 'Learning Support Assistant - Basildon, Essex Do you have experience working in a primary school? Would you like to join a team of supportive and friendly staff who go above and beyond for the pupils? Perhaps, you would like a school that offers teacher training, supporting you while you train? If you answered yes to any of these, then Academics would love to hear from you! ** Basildon, Essex ** April 2026 start ** Long term contract until July 2... ',
#   'applications': 12,
#   'jobUrl': 'https://www.reed.co.uk/jobs/learning-support-assistant/56687088'},
#  {'jobId': 56719015,
#   'employerId': 423001,
#   'employerName': 'Owen Daniels ',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Mechanical Manager',
#   'locationName': 'Manchester',
#   'minimumSalary': None,
#   'maximumSalary': None,
#   'currency': None,
#   'expirationDate': '12/05/2026',
#   'date': '31/03/2026',
#   'jobDescription': 'Mechanical Manager Are you an experienced Mechanical Manager looking for a new role? Do you have a strong background in engineering design within a fabrication environment and the ability to lead or develop a team? If so, this opportunity could be ideal for you. Our client, an engineering company specialising in the oil and gas sector, is looking for a skilled and motivated Mechanical Manager to join their growing team. The successful candidate ... ',
#   'applications': 5,
#   'jobUrl': 'https://www.reed.co.uk/jobs/mechanical-manager/56719015'},
#  {'jobId': 56687085,
#   'employerId': 673923,
#   'employerName': 'Space 8 Recruitment',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'IHT Advisor',
#   'locationName': 'Solihull',
#   'minimumSalary': None,
#   'maximumSalary': None,
#   'currency': None,
#   'expirationDate': '04/05/2026',
#   'date': '23/03/2026',
#   'jobDescription': 'We are seeking a knowledgeable and dedicated Inheritance Tax (IHT) Advisor to join a growing team at a leading financial advisory firm. This role is pivotal in providing expert guidance to clients on inheritance tax planning and compliance, ensuring they navigate the complexities of tax legislation effectively. You will work closely with clients to develop tailored strategies that optimise their estate planning and minimise tax liabilities. Key ... ',
#   'applications': 3,
#   'jobUrl': 'https://www.reed.co.uk/jobs/iht-advisor/56687085'},
#  {'jobId': 56719014,
#   'employerId': 377106,
#   'employerName': 'Robert Walters',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Regulatory Counsel - 3+ PQE (Global Investment Bank)',
#   'locationName': 'London',
#   'minimumSalary': None,
#   'maximumSalary': None,
#   'currency': None,
#   'expirationDate': '12/05/2026',
#   'date': '31/03/2026',
#   'jobDescription': 'Robert Walters have partnered with a top-tier investment bank who is seeking a Regulatory Counsel with at least three years of post-qualification experience to join their London-based legal team. This is an exceptional opportunity to join a globally recognised financial institution offering exposure to complex regulatory matters across derivatives, funding products, and capital markets documentation, providing you with intellectually stimulating... ',
#   'applications': 2,
#   'jobUrl': 'https://www.reed.co.uk/jobs/regulatory-counsel-3-pqe-global-investment-bank/56719014'},
#  {'jobId': 56707982,
#   'employerId': 424378,
#   'employerName': 'ETS Consulting Ltd',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Mechanical Maintenance Engineer',
#   'locationName': 'High Peak',
#   'minimumSalary': 40000.0,
#   'maximumSalary': 43234.0,
#   'currency': 'GBP',
#   'expirationDate': '08/05/2026',
#   'date': '27/03/2026',
#   'jobDescription': 'Mechanical Maintenance Engineer Double Days (6-2pm/2-10pm) Mon-Thurs &amp; Fridays 6-12pm / 12-6pm Salary: 43,234 + Pension + Holidays + Sick pay scheme + Staff shop + subsidized canteen + Standard OT rate + 300 bonus Location: High Peak Reference: Jo7055/PW The Company An excellent opportunity has arisen with a UK owned leading food manufacturer, a growing and supportive organisation. The Company are extremely well established with over 85 year... ',
#   'applications': 2,
#   'jobUrl': 'https://www.reed.co.uk/jobs/mechanical-maintenance-engineer/56707982'},
#  {'jobId': 56719013,
#   'employerId': 402975,
#   'employerName': 'Marks Sattin',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Accounts Receivable Supervisor',
#   'locationName': 'London',
#   'minimumSalary': 146.0,
#   'maximumSalary': 165.0,
#   'currency': 'GBP',
#   'expirationDate': '12/05/2026',
#   'date': '31/03/2026',
#   'jobDescription': "Accounts Receivable Supervisor (Ongoing Temp) - Immediate Start Required Hotel sector experience is an absolute MUST We're looking for an Accounts Receivable Supervisor who can hit the ground running in a fast-paced, multi-site hotel environment. This ongoing temporary role needs someone immediately available, highly organised, and confident leading day-to-day AR operations. Duties: Oversee daily AR workflows, including managing the team inbox a... ",
#   'applications': 15,
#   'jobUrl': 'https://www.reed.co.uk/jobs/accounts-receivable-supervisor/56719013'},
#  {'jobId': 56707981,
#   'employerId': 575264,
#   'employerName': 'Reed',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Management Accountant',
#   'locationName': 'NE129UP',
#   'minimumSalary': None,
#   'maximumSalary': None,
#   'currency': None,
#   'expirationDate': '27/04/2026',
#   'date': '27/03/2026',
#   'jobDescription': 'Management Accountant&nbsp; Location : NE12 Salary : Negotiable depending on experience Job Type : Permanent, Part-Time (hours negotiable) We are recruiting on behalf of a Newcastle-based construction company seeking an experienced Management Accountant to join their team in a key standalone role.&nbsp;This position involves supporting the financial management of multiple projects and ensuring accurate reporting across all stages. You will work ... ',
#   'applications': 4,
#   'jobUrl': 'https://www.reed.co.uk/jobs/management-accountant/56707981'},
#  {'jobId': 56719012,
#   'employerId': 524744,
#   'employerName': 'Hays Specialist Recruitment Limited',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Cyber Security Specialist (SecOps/GRC)',
#   'locationName': 'LE16DN',
#   'minimumSalary': 40000.0,
#   'maximumSalary': 47500.0,
#   'currency': 'GBP',
#   'expirationDate': '12/05/2026',
#   'date': '31/03/2026',
#   'jobDescription': "Cyber Security Specialist (SecOps/GRC) Permanent Salary: Between 40,000 - 47,500 Leicester - Hybrid - 2-3 days a week Your new company I'm on the lookout for a Cyber Security Specialist with some experience spanning technical security operations and GRC. The ideal candidate is someone with fundamental security operations experience (SIEM, EDR, Vulnerability), who has also worked in alignment with any security frameworks. If you've handled audits... ",
#   'applications': 6,
#   'jobUrl': 'https://www.reed.co.uk/jobs/cyber-security-specialist-secops-grc/56719012'},
#  {'jobId': 56707980,
#   'employerId': 378181,
#   'employerName': 'eSift Ltd',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Customer Support Executive',
#   'locationName': 'GU148BL',
#   'minimumSalary': 26000.0,
#   'maximumSalary': 28000.0,
#   'currency': 'GBP',
#   'expirationDate': '25/04/2026',
#   'date': '27/03/2026',
#   'jobDescription': 'Our client is a leading supplier of life saving medical and training equipment which they distribute across Europe.&nbsp; Working closely with healthcare organisations, charities and emergency services to improve access to high quality, easy to use equipment that supports the chain of survival in medical emergencies.&nbsp; They are currently recruiting for a Customer Support Executive to join their small support team.&nbsp; &nbsp; Location: &nbs... ',
#   'applications': 15,
#   'jobUrl': 'https://www.reed.co.uk/jobs/customer-support-executive/56707980'},
#  {'jobId': 56714926,
#   'employerId': 520857,
#   'employerName': 'BTG Recruitment',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Accounts Assistant',
#   'locationName': 'LE131GA',
#   'minimumSalary': 28000.0,
#   'maximumSalary': 32000.0,
#   'currency': 'GBP',
#   'expirationDate': '30/04/2026',
#   'date': '30/03/2026',
#   'jobDescription': 'Accounts Assistant ?? Near Melton Mowbray (Office-based) ?? 30,000- 32,000 A growing, owner-managed business is looking for a hands-on Accounts Assistant to take ownership of its day-to-day finance function. This is a great opportunity for someone who enjoys variety, autonomy, and being at the heart of a business where finance genuinely makes an impact. The Role – Accounts Assistant As the Accounts Assistant , you’ll be responsible for managing ... ',
#   'applications': 20,
#   'jobUrl': 'https://www.reed.co.uk/jobs/accounts-assistant/56714926'},
#  {'jobId': 56687083,
#   'employerId': 182165,
#   'employerName': 'Douglas Scott Legal Recruitment ',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Casualty Solicitor',
#   'locationName': 'B11AY',
#   'minimumSalary': 55000.0,
#   'maximumSalary': 75000.0,
#   'currency': 'GBP',
#   'expirationDate': '21/04/2026',
#   'date': '23/03/2026',
#   'jobDescription': 'Associate Solicitor / Senior Associate Solicitor- Casualty Solicitor Location: Birmingham Salary: 75,000 DOE + Bonus My client is looking to bring in an Associate / Senior Associate to join their Casualty team. The team has seen an influx of work from both new and old clients, and due to this increase of work they looking to expand their team. In this role you will be managing your own caseload that will predominantly consist of high value large... ',
#   'applications': 2,
#   'jobUrl': 'https://www.reed.co.uk/jobs/casualty-solicitor/56687083'},
#  {'jobId': 56687084,
#   'employerId': 279225,
#   'employerName': 'CMD Recruitment',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Office Administrator',
#   'locationName': 'Andover',
#   'minimumSalary': 31076.0,
#   'maximumSalary': 31076.0,
#   'currency': 'GBP',
#   'expirationDate': '04/05/2026',
#   'date': '23/03/2026',
#   'jobDescription': 'Office Administrator 31,076 per annum + benefits Andover, Hampshire Permanent Are you an organised administrator who thrives in a varied, fast-paced office environment? Do you enjoy being the central point of contact and keeping operations running smoothly behind the scenes? If so, this could be a fantastic opportunity for you. My client is seeking an experienced Office Administrator to join their busy and well-established team in Andover. This ... ',
#   'applications': 21,
#   'jobUrl': 'https://www.reed.co.uk/jobs/office-administrator/56687084'},
#  {'jobId': 56707979,
#   'employerId': 504568,
#   'employerName': 'Aspire People Limited',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Learning Support Assistant',
#   'locationName': 'DN211PU',
#   'minimumSalary': 103.0,
#   'maximumSalary': 110.0,
#   'currency': 'GBP',
#   'expirationDate': '08/05/2026',
#   'date': '27/03/2026',
#   'jobDescription': 'Aspire People are recruiting for a Learning Support Assistant to support pupils with special educational needs in a school located in Gainsborough, Lincolnshire. This role is to work full-time, on a temp to perm basis starting immediately! The working hours are 08:30 - 15:30 and you will be working 1:1 or in small groups with students with various learning difficulties and special educational needs. The role requires high level of resilience and... ',
#   'applications': 2,
#   'jobUrl': 'https://www.reed.co.uk/jobs/learning-support-assistant/56707979'},
#  {'jobId': 56707978,
#   'employerId': 477350,
#   'employerName': 'Michael Page Finance',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Corporate Tax Manager',
#   'locationName': 'Manchester',
#   'minimumSalary': None,
#   'maximumSalary': None,
#   'currency': None,
#   'expirationDate': '08/05/2026',
#   'date': '27/03/2026',
#   'jobDescription': 'The Corporate Tax Manager will oversee tax compliance and advisory services for a not-for-profit organisation, ensuring adherence to regulations and optimising tax strategies. Based in Manchester, this role offers a rewarding opportunity to make an impact in the tax department while working in a hybrid environment. Client Details This not-for-profit organisation is a well-established entity in its sector, operating as a medium-sized organisation... ',
#   'applications': 0,
#   'jobUrl': 'https://www.reed.co.uk/jobs/corporate-tax-manager/56707978'},
#  {'jobId': 56707975,
#   'employerId': 671103,
#   'employerName': 'Law Staff Limited',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Construction Solicitor',
#   'locationName': 'EC2M7DT',
#   'minimumSalary': 75000.0,
#   'maximumSalary': 90000.0,
#   'currency': 'GBP',
#   'expirationDate': '08/05/2026',
#   'date': '27/03/2026',
#   'jobDescription': 'Our client based in the heart of the City, recognised within the Legal 500 are seeking to add a Senior Associate Solicitor within the area of Construction Law. Minimum of 4 years+ PQE.&nbsp;Hybrid working, private healthcare and life assurance are some of the many benefits on offer.&nbsp; Due to expansion, our client is seeking an ambitious non-contentious construction solicitor, someone with confidence in advising and negotiating construction c... ',
#   'applications': 1,
#   'jobUrl': 'https://www.reed.co.uk/jobs/construction-solicitor/56707975'},
#  {'jobId': 56719011,
#   'employerId': 2763,
#   'employerName': 'ADLIB',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Account Executive',
#   'locationName': 'BA11SU',
#   'minimumSalary': 24000.0,
#   'maximumSalary': 26000.0,
#   'currency': 'GBP',
#   'expirationDate': '12/05/2026',
#   'date': '31/03/2026',
#   'jobDescription': 'We are looking for an entry level Account Executive&nbsp;to join a dynamic client delivery team at an esablished marketing agency in Bath. You’ll help manage administration, reporting, and coordination across client projects. You will work closely with Account Directors, Account Managers, and Delivery Leads to ensure smooth delivery and excellent client service. This role is ideal if you enjoy organising, supporting teams, and developing operati... ',
#   'applications': 10,
#   'jobUrl': 'https://www.reed.co.uk/jobs/account-executive/56719011'},
#  {'jobId': 56687082,
#   'employerId': 325295,
#   'employerName': 'Perfect Placement Uk Ltd',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Senior Technician',
#   'locationName': 'DA11DY',
#   'minimumSalary': 55000.0,
#   'maximumSalary': 55000.0,
#   'currency': 'GBP',
#   'expirationDate': '04/05/2026',
#   'date': '23/03/2026',
#   'jobDescription': 'Our client, a reputable and well-established family-run Service Centre in Dartford, is seeking to appoint a dedicated Senior Technician. This is an exceptional opportunity for a skilled Senior Technician looking to progress their career within a friendly, professional environment that services all makes and models. Benefits: Competitive basic salary ranging from 45,000 to 55,000, depending on experience Optional overtime on Saturdays for extra e... ',
#   'applications': 5,
#   'jobUrl': 'https://www.reed.co.uk/jobs/senior-technician/56687082'},
#  {'jobId': 56719010,
#   'employerId': 524744,
#   'employerName': 'Hays Specialist Recruitment Limited',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'KS2 Teaching Assistant - SEN',
#   'locationName': 'Wirral',
#   'minimumSalary': None,
#   'maximumSalary': None,
#   'currency': None,
#   'expirationDate': '12/05/2026',
#   'date': '31/03/2026',
#   'jobDescription': 'Job Title: Key Stage 2 Teaching Assistant, SEND Children (1-2-1) Location: Wirral Pay: 95 to 100 (Experience Dependent) Working pattern: Part-Time, Full-Time, Term-Time Contract: Starting from April onwards Your new company Hays is a leading education recruiter offering day-to-day positions as well as full-time positions in the Wirral area with a role for Level 2 and above qualified teaching assistant looking to start in March. We specialise in ... ',
#   'applications': 1,
#   'jobUrl': 'https://www.reed.co.uk/jobs/ks2-teaching-assistant-sen/56719010'},
#  {'jobId': 56707974,
#   'employerId': 695751,
#   'employerName': '\t Manor Green School',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Apprentice Specialist Support Assistant',
#   'locationName': 'SL63EQ',
#   'minimumSalary': 12.21,
#   'maximumSalary': 12.21,
#   'currency': 'GBP',
#   'expirationDate': '13/04/2026',
#   'date': '27/03/2026',
#   'jobDescription': 'Apprentice Specialist Support Assistant 18 month fixed term contract to start asap Full Time 32.5 hours, term time only 12.21 per hour apprenticeship rate ( 13.60 after 6 months) Teaching Assistant Level 3 Apprenticeship As an Apprentice SSA you will work with the classroom teacher to support students’ independent learning and progress in accordance with the national curriculum and with behaviour management strategies. You will help prepare reso... ',
#   'applications': 6,
#   'jobUrl': 'https://www.reed.co.uk/jobs/apprentice-specialist-support-assistant/56707974'},
#  {'jobId': 56687080,
#   'employerId': 134670,
#   'employerName': 'Penguin Recruitment Ltd',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Architectural Technician',
#   'locationName': 'Durham',
#   'minimumSalary': 32000.0,
#   'maximumSalary': 40000.0,
#   'currency': 'GBP',
#   'expirationDate': '04/05/2026',
#   'date': '23/03/2026',
#   'jobDescription': 'Job Title: Architectural Technician Ref: BM079 Location: Durham Salary: 32,000 - 40,000 This is an excellent opportunity to join one of the Norths leading RIBA chartered practice who provide award-winning design services to the commercial, education, healthcare, industrial, and residential sectors. They are on the lookout for an enthusiastic and experienced Architectural Technologist. Benefits for the role of Architectural Technician include: Hi... ',
#   'applications': 5,
#   'jobUrl': 'https://www.reed.co.uk/jobs/architectural-technician/56687080'},
#  {'jobId': 56719008,
#   'employerId': 410694,
#   'employerName': 'Pareto',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'BD Grad Scheme',
#   'locationName': 'Exeter',
#   'minimumSalary': 35000.0,
#   'maximumSalary': 45000.0,
#   'currency': 'GBP',
#   'expirationDate': '28/04/2026',
#   'date': '31/03/2026',
#   'jobDescription': "Job Title: Graduate Scheme - Business Development (Commercial) Salary: 35k basic salary/ with 45k OTE Our client are looking for ambitious graduates to help enhance their presence, to generate revenue by capitalising on warm leads and opening the door to new ones, thereby increasing their book of business with a customer-led approach. There is no limit to where you can go with our client - so if you've got a degree, excellent communication skill... ",
#   'applications': 1,
#   'jobUrl': 'https://www.reed.co.uk/jobs/bd-grad-scheme/56719008'},
#  {'jobId': 56707973,
#   'employerId': 575264,
#   'employerName': 'Reed',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Systems Engineer',
#   'locationName': 'RH13DR',
#   'minimumSalary': 45000.0,
#   'maximumSalary': 50000.0,
#   'currency': 'GBP',
#   'expirationDate': '27/04/2026',
#   'date': '27/03/2026',
#   'jobDescription': 'Systems Engineer – UK MoD &amp; Government Systems Location: Redhill (UK) Salary: 45,000 to 50,000 Are you an experienced Systems Engineer with a passion for delivering secure, technically robust solutions for government and defence environments? This is an exciting opportunity to play a key role in designing, configuring and delivering mission-critical systems that support national security and operational capability. You’ll join a proactive en... ',
#   'applications': 9,
#   'jobUrl': 'https://www.reed.co.uk/jobs/systems-engineer/56707973'},
#  {'jobId': 56719007,
#   'employerId': 377106,
#   'employerName': 'Robert Walters',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Mid Market Account Manager',
#   'locationName': 'London',
#   'minimumSalary': 42000.0,
#   'maximumSalary': 50000.0,
#   'currency': 'GBP',
#   'expirationDate': '12/05/2026',
#   'date': '31/03/2026',
#   'jobDescription': "Our client is a unicorn, AI-powered customer communications platform used by 22,000+ companies worldwide to drive revenue, resolve issues faster, and scale customer-facing teams. Theyre redefining customer communications by bringing voice, SMS, WhatsApp, and AI together into one seamless workspace. They help teams work smarter, not harder. our client's AI Voice Agent automates routine calls, AI Assist streamlines post-call work, and AI Assist Pr... ",
#   'applications': 15,
#   'jobUrl': 'https://www.reed.co.uk/jobs/mid-market-account-manager/56719007'},
#  {'jobId': 56707972,
#   'employerId': 150660,
#   'employerName': 'Key Recruitment Ltd',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Frontline Advisor',
#   'locationName': 'Portsmouth',
#   'minimumSalary': 13.0,
#   'maximumSalary': 13.0,
#   'currency': 'GBP',
#   'expirationDate': '08/05/2026',
#   'date': '27/03/2026',
#   'jobDescription': 'Immediate Start – Frontline Welfare Advisor (Charity Sector) | 40 Hours per Week Are you passionate about making a real difference in people’s lives? Do you have experience providing advice and support in social welfare issues? If so, i want to hear from you TODAY! My client is looking for a dedicated and compassionate Frontline Welfare Advisor to join the team immediately. This is a fast-paced, client-facing role where you’ll be supporting indi... ',
#   'applications': 2,
#   'jobUrl': 'https://www.reed.co.uk/jobs/frontline-advisor/56707972'},
#  {'jobId': 56687079,
#   'employerId': 332399,
#   'employerName': 'Sanctuary Personnel',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Social Worker - Mental Health Team',
#   'locationName': 'Enfield',
#   'minimumSalary': None,
#   'maximumSalary': None,
#   'currency': None,
#   'expirationDate': '04/05/2026',
#   'date': '23/03/2026',
# ...
#   'applications': 5,
#   'jobUrl': 'https://www.reed.co.uk/jobs/bookkeeper/56687067'},
#  {'jobId': 56714908,
#   'employerId': 572151,
#   'employerName': 'Thomas Professional ',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Delivery Driver',
#   'locationName': 'GL501JZ',
#   'minimumSalary': 25392.28,
#   'maximumSalary': 25392.28,
#   'currency': 'GBP',
#   'expirationDate': '12/05/2026',
#   'date': '30/03/2026',
#   'jobDescription': 'Job Title: Delivery Driver Location: Cheltenham Contract Type: Temp to Perm Contract Length: 12 weeks Start Date: As soon as possible Salary: 25,392.28 per annum ·&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 13.33 weekly driving bonus ·&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Guaranteed 20.00 weekly commission About the Role We are looking for a reliable and motivated Delivery Driver (Milk Roundsperson) to join our team. This is a phy... ',
#   'applications': 0,
#   'jobUrl': 'https://www.reed.co.uk/jobs/delivery-driver/56714908'},
#  {'jobId': 56707960,
#   'employerId': 351049,
#   'employerName': 'Ann Pettengell',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Project Manager',
#   'locationName': 'CB30FA',
#   'minimumSalary': 24.85,
#   'maximumSalary': 24.85,
#   'currency': 'GBP',
#   'expirationDate': '08/05/2026',
#   'date': '27/03/2026',
#   'jobDescription': 'Are you an experienced programme manager with a passion for cutting-edge research? We are looking for a Head of Projects to lead the administration and delivery of a portfolio of high-profile telecommunications research initiatives. This is a unique opportunity to work at the forefront of next-generation communications technologies, including emerging wireless networks. About the Role You will take ownership of complex, multi-partner research pr... ',
#   'applications': 8,
#   'jobUrl': 'https://www.reed.co.uk/jobs/project-manager/56707960'},
#  {'jobId': 56718997,
#   'employerId': 409156,
#   'employerName': 'Cameron James',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Mortgage Broker',
#   'locationName': 'Bristol',
#   'minimumSalary': 27000.0,
#   'maximumSalary': 55000.0,
#   'currency': 'GBP',
#   'expirationDate': '12/05/2026',
#   'date': '31/03/2026',
#   'jobDescription': 'Mortgage Advisor / Mortgage Broker – Bristol – High Earnings Location: Bristol Salary: 27,000 – 29,000 (including car allowance) + Commission + Bonus OTE: 55,000 Year 1 | 75,000+ thereafter | High Earnings Job Type: Full-Time, Permanent Recruiter: Cameron James Professional Recruitment Cameron James Professional Recruitment is proud to be working with a highly successful estate agency to recruit an experienced Mortgage Advisor / Mortgage Broker ... ',
#   'applications': 0,
#   'jobUrl': 'https://www.reed.co.uk/jobs/mortgage-broker/56718997'},
#  {'jobId': 56707959,
#   'employerId': 468382,
#   'employerName': 'Lynn Bennett Resourcing',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'HR Administrator',
#   'locationName': 'NE11AD',
#   'minimumSalary': 24500.0,
#   'maximumSalary': 29000.0,
#   'currency': 'GBP',
#   'expirationDate': '08/05/2026',
#   'date': '27/03/2026',
#   'jobDescription': 'Our client is a professional services business, with a strong reputation. Reporting to the Head of People (who is fantastic), the HR Administrator is central to ensuring a seamless employee experience, from onboarding through to day-to-day HR administration. What you will be doing Support the full employee lifecycle from onboarding and induction through to leaver administration Maintain accurate HR records and HRIS data in line with GDPR and int... ',
#   'applications': 16,
#   'jobUrl': 'https://www.reed.co.uk/jobs/hr-administrator/56707959'},
#  {'jobId': 56707958,
#   'employerId': 600676,
#   'employerName': 'OAL Group',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Project Coordinator',
#   'locationName': 'PE26YN',
#   'minimumSalary': 35000.0,
#   'maximumSalary': 40000.0,
#   'currency': 'GBP',
#   'expirationDate': '08/05/2026',
#   'date': '27/03/2026',
#   'jobDescription': 'Project Coordinator Location : Peterborough | Full-time, Permanent | 35k - 40k, depending on experience OAL are looking for an organised and motivated Project Coordinator to join our team in Peterborough. Reporting to the Commercial Director, you will play a key role in keeping our projects running smoothly. This is a hands-on coordination role where you will plan and track activities, manage schedules, liaise with customers and suppliers, and k... ',
#   'applications': 21,
#   'jobUrl': 'https://www.reed.co.uk/jobs/project-coordinator/56707958'},
#  {'jobId': 56718996,
#   'employerId': 588076,
#   'employerName': 'Pertemps London',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Maintenance Operative',
#   'locationName': 'WC1V7LL',
#   'minimumSalary': 35000.0,
#   'maximumSalary': 35000.0,
#   'currency': 'GBP',
#   'expirationDate': '12/05/2026',
#   'date': '31/03/2026',
#   'jobDescription': 'Maintenance Operative Location: London (Within the M25) Salary: 35,000 + Company Vehicle &amp; Tools Hours: Full Time, 40 hours per week (Monday to Friday, with occasional weekend work if required) Are you a skilled Maintenance Operative looking for a varied, hands-on role where no two days are the same? We are looking for an experienced and reliable Maintenance Operative to support a portfolio of sites across London. This is a field-based role ... ',
#   'applications': 13,
#   'jobUrl': 'https://www.reed.co.uk/jobs/maintenance-operative/56718996'},
#  {'jobId': 56687066,
#   'employerId': 62599,
#   'employerName': 'Source4 Personnel Solutions',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Sales Coordinator',
#   'locationName': 'Bracknell',
#   'minimumSalary': None,
#   'maximumSalary': None,
#   'currency': None,
#   'expirationDate': '04/05/2026',
#   'date': '23/03/2026',
#   'jobDescription': 'Our client is looking for: A motivated Sales Coordinator to join their UK Sales team. This role is ideal for someone with previous sales administration or sales support experience who is interested in developing a career in sales within a commercial, fast-paced environment. The role offers a strong foundation for progression within a sales career. Role Overview: The Sales Coordinator will act as a central point of contact for both customers and ... ',
#   'applications': 18,
#   'jobUrl': 'https://www.reed.co.uk/jobs/sales-coordinator/56687066'},
#  {'jobId': 56707957,
#   'employerId': 604757,
#   'employerName': 'Silcom Recruitment Limited',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Diagnostic Technician',
#   'locationName': 'Portsmouth',
#   'minimumSalary': 42000.0,
#   'maximumSalary': 45000.0,
#   'currency': 'GBP',
#   'expirationDate': '08/05/2026',
#   'date': '27/03/2026',
#   'jobDescription': 'The Role: Silcom Recruitment is actively seeking an experienced Diagnostic Technician on behalf of one of our highly regarded and forward thinking clients, based on the outskirts of Portsmouth. Our client is offering a fantastic opportunity for a skilled and dedicated Diagnostic Technician to join their professional workshop team. This position will see you working with a wide range of modern vehicles, focusing on advanced diagnostics, fault fin... ',
#   'applications': 0,
#   'jobUrl': 'https://www.reed.co.uk/jobs/diagnostic-technician/56707957'},
#  {'jobId': 56687065,
#   'employerId': 477350,
#   'employerName': 'Michael Page Finance',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Assistant Accountant',
#   'locationName': 'TN128ET',
#   'minimumSalary': 30000.0,
#   'maximumSalary': 35000.0,
#   'currency': 'GBP',
#   'expirationDate': '20/04/2026',
#   'date': '23/03/2026',
#   'jobDescription': 'Are you an aspiring Assistant Accountant with a keen interest in financial services? This permanent role in Goudhurst offers an excellent opportunity to develop your expertise in accounting and finance within a professional setting. Client Details This small-sized organisation operates within the accountancy industry, providing tailored accounting and finance solutions to its clients. Their focus lies on precision and efficiency, with a commitme... ',
#   'applications': 6,
#   'jobUrl': 'https://www.reed.co.uk/jobs/assistant-accountant/56687065'},
#  {'jobId': 56707956,
#   'employerId': 424664,
#   'employerName': 'Larbey Evans',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Senior Legal Technology Specialist',
#   'locationName': 'EC2N4BQ',
#   'minimumSalary': 65000.0,
#   'maximumSalary': 75000.0,
#   'currency': 'GBP',
#   'expirationDate': '08/05/2026',
#   'date': '27/03/2026',
#   'jobDescription': 'Senior Legal Technology Specialist Top-tier US law at the forefront of legal tech and innovation is seeking a Senior Legal Technology Specialist, someone who can not only support but actively drive the development and implementation of cutting-edge legal technology strategies and tools. Salary to 75,000 Generous employee benefits 100 monthly employee contribution Complimentary lunch once a week Hybrid working – 4 days in the office / 1 day remot... ',
#   'applications': 2,
#   'jobUrl': 'https://www.reed.co.uk/jobs/senior-legal-technology-specialist/56707956'},
#  {'jobId': 56718995,
#   'employerId': 475688,
#   'employerName': 'VIQU IT Recruitment',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'IT Support Analyst',
#   'locationName': 'Leamington Spa',
#   'minimumSalary': 29000.0,
#   'maximumSalary': 30000.0,
#   'currency': 'GBP',
#   'expirationDate': '12/05/2026',
#   'date': '31/03/2026',
#   'jobDescription': 'IT Support Analyst Leamington Spa – Onsite 29,000 - 30,000 VIQU have partnered with a leading organisation seeking an IT Support Analyst to join their expanding team. This IT Support Analyst role offers hands-on, face-to-face 1st and 2nd line support within a fast-paced environment. As an IT Support Analyst, you’ll work closely with a small team, delivering excellent user support across a modern Microsoft environment. Key Responsibilities of the... ',
#   'applications': 23,
#   'jobUrl': 'https://www.reed.co.uk/jobs/it-support-analyst/56718995'},
#  {'jobId': 56718994,
#   'employerId': 694291,
#   'employerName': 'Premier Pits',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Technical Sales Representative',
#   'locationName': 'Spalding',
#   'minimumSalary': None,
#   'maximumSalary': None,
#   'currency': None,
#   'expirationDate': '28/04/2026',
#   'date': '31/03/2026',
#   'jobDescription': 'Technical Sales Representative Location:&nbsp; Spalding, Lincolnshire Salary:&nbsp; Competitive Due to the continued expansion of Premier Pits, we are looking for an experienced Technical Sales Representative to join our Sales team. For over 35 years, Premier Pits have been designing, manufacturing and installing a range of prefabricated steel maintenance pits for the commercial vehicle, PSV and Rail industries across the UK and internationally.... ',
#   'applications': 3,
#   'jobUrl': 'https://www.reed.co.uk/jobs/technical-sales-representative/56718994'},
#  {'jobId': 56718993,
#   'employerId': 410694,
#   'employerName': 'Pareto',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Commercial Graduate Scheme',
#   'locationName': 'Exeter',
#   'minimumSalary': 35000.0,
#   'maximumSalary': 45000.0,
#   'currency': 'GBP',
#   'expirationDate': '28/04/2026',
#   'date': '31/03/2026',
#   'jobDescription': "Job Title: Commercial Associate Graduate Scheme Sector: Tech Today, our client partners with thousands of companies across the UK and Europe. With yearly growth of 40%, they're a thoroughly exciting proposition for any candidate looking to start their career. Uniquely positioned within their market verticals, they're immediately recognisable the world over, a truly gigantic brand! They're now looking for a brand new team of Graduates as they loo... ",
#   'applications': 1,
#   'jobUrl': 'https://www.reed.co.uk/jobs/commercial-graduate-scheme/56718993'},
#  {'jobId': 56718992,
#   'employerId': 449259,
#   'employerName': 'Rise Technical Recruitment Limited',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Electrician',
#   'locationName': 'Weybridge',
#   'minimumSalary': 40000.0,
#   'maximumSalary': 46000.0,
#   'currency': 'GBP',
#   'expirationDate': '12/05/2026',
#   'date': '31/03/2026',
#   'jobDescription': 'An excellent opportunity for a Gold Card qualified Electrician looking to join a rapidly expanding business who can offer further training and long term progression opportunities. Are you a Gold Card qualified Electrician? Would you like to progress your career at a rapidly expanding company? This well established company provide electrical services to clients across the UK. They have grown rapidly in recent years, winning a number of high profi... ',
#   'applications': 3,
#   'jobUrl': 'https://www.reed.co.uk/jobs/electrician/56718992'},
#  {'jobId': 56687062,
#   'employerId': 561913,
#   'employerName': 'Randstad Construction & Property',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Admin',
#   'locationName': 'Manchester',
#   'minimumSalary': 14.0,
#   'maximumSalary': 15.0,
#   'currency': 'GBP',
#   'expirationDate': '04/05/2026',
#   'date': '23/03/2026',
#   'jobDescription': 'Construction Site Admin Manchester 2 years 14/hour Are you a highly organised multitasker who thrives in a fast-paced environment? We are looking for a proactive Temporary Site Administrator to join our team and help keep our upcoming construction project running smoothly. Key Responsibilities Managing daily site attendance, visitor logs, and time sheets. Processing delivery tickets, invoices, and material orders. Maintaining and updating health... ',
#   'applications': 123,
#   'jobUrl': 'https://www.reed.co.uk/jobs/admin/56687062'},
#  {'jobId': 56687063,
#   'employerId': 477350,
#   'employerName': 'Michael Page Finance',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Private Client Tax Senior Manager',
#   'locationName': 'Redhill',
#   'minimumSalary': 70000.0,
#   'maximumSalary': 80000.0,
#   'currency': 'GBP',
#   'expirationDate': '20/04/2026',
#   'date': '23/03/2026',
#   'jobDescription': 'This is an excellent opportunity for a Private Client Tax Senior Manager to lead and manage a portfolio of private clients, providing strategic tax advice and compliance services. Based in Redhill, this role is ideal for a tax professional looking to progress their career within the professional services industry. Client Details This position is with a well-established professional services firm that specialises in providing expert tax advice an... ',
#   'applications': 0,
#   'jobUrl': 'https://www.reed.co.uk/jobs/private-client-tax-senior-manager/56687063'},
#  {'jobId': 56718989,
#   'employerId': 657880,
#   'employerName': 'Certain Advantage',
#   'employerProfileId': None,
#   'employerProfileName': None,
#   'jobTitle': 'Integration Lead Engineer – Vehicle Efficiency',
#   'locationName': 'CV350BJ',
#   'minimumSalary': 30.0,
#   'maximumSalary': 34.0,
#   'currency': 'GBP',
#   'expirationDate': '28/04/2026',
#   'date': '31/03/2026',
#   'jobDescription': 'Integration Lead Engineer – Vehicle Efficiency Certain Advantage is hiring for an Integration Lead Engineer – Vehicle Efficiency based in the Warwickshire area . This role is on a contract basis and is site-based. The Company We’re working with a Manufacturing business that blends British craftsmanship with cutting-edge innovation to create luxury vehicles that redefine performance and style. Does this sound like your next career move? If you’re... ',
#   'applications': 1,
#   'jobUrl': 'https://www.reed.co.uk/jobs/integration-lead-engineer--vehicle-efficiency/56718989'}]

# %%
response
# Out:
# <Response [200]>

# %%
import requests
import json

# المعرفات الخاصة بك
FT_CLIENT_ID = "PAR_jobintelligentaimatch_b2f7ec13449756bd20374a408837222a62ac61f1d8ae6e9ff3b03250de8a742d"
FT_CLIENT_SECRET = "966c719126e901c92aa91a394f3d93f6a3ace5cc738a396158635be37ba5adb4"
AUTH_URL = "https://entreprise.pole-emploi.fr/connexion/oauth2/access_token?realm=%2Fpartenaire"

def get_access_token():
    payload = {
        'grant_type': 'client_credentials',
        'scope': 'api_offresdemploiv2'
    }
    try:
        print("🔑 Attempting to get access token...", flush=True)
        response = requests.post(
            AUTH_URL, 
            data=payload, 
            auth=(FT_CLIENT_ID, FT_CLIENT_SECRET),
            headers={'Content-Type': 'application/x-www-form-urlencoded'},
            timeout=10
        )
        if response.status_code == 200:
            return response.json().get('access_token')
        print(f"❌ Auth Error {response.status_code}: {response.text}", flush=True)
    except Exception as e:
        print(f"⚠️ Auth Exception: {e}", flush=True)
    return None

def fetch_job_offers(token):
    # بناء الرابط يدوياً للتأكد من عدم وجود //
    base_url = "https://api.francetravail.io/partenaire/offresdemploiv2/v2/offres/search"
    endpoint = "/partenaire/offresdemploiv2/v2/offres/search"
    SEARCH_URL = base_url + endpoint
    
    headers = {
        'Authorization': f'Bearer {token}',
        'Accept': 'application/json'
    }
    
    params = {
        'motsCles': 'Data Engineer',
        'range': '0-9'
    }

    try:
        print(f"🚀 Connecting to: {SEARCH_URL}", flush=True)
        response = requests.get(SEARCH_URL, headers=headers, params=params, timeout=20)
        
        if response.status_code == 200:
            with open('jobs_bronze.json', 'w', encoding='utf-8') as f:
                json.dump(response.json(), f, ensure_ascii=False, indent=4)
            print("✅ مبروك! تم سحب البيانات بنجاح في jobs_bronze.json", flush=True)
        else:
            print(f"❌ API Error {response.status_code}: {response.text}", flush=True)
            
    except Exception as e:
        print(f"⚠️ Connection Error: {e}", flush=True)

if __name__ == "__main__":
    print("🎬 Starting Script...", flush=True)
    token = get_access_token()
    if token:
        print(f"✅ Token Obtained: {token[:10]}...", flush=True)
        fetch_job_offers(token)
# Out:
# 🎬 Starting Script...
# 🔑 Attempting to get access token...
# ✅ Token Obtained: LoxDxc3Hvd...
# 🚀 Connecting to: https://api.francetravail.io/partenaire/offresdemploiv2/v2/offres/search/partenaire/offresdemploiv2/v2/offres/search
# ❌ API Error 401: TypeAuth invalide ou non renseigné
